# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("covid_19_country_wise_latest.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
replacing_index = data.rename(columns = {'Unnamed: 0': 'Index'},inplace = True)
data.head()
# Out:
#    Index Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0      0    Afghanistan      36263   1269      25198    9796      106.0
# 1      1        Albania       4880    144       2745    1991      117.0
# 2      2        Algeria      27973   1163      18837    7973      616.0
# 3      3        Andorra        907     52        803      52       10.0
# 4      4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.columns = data.columns.str.replace(' ', '_')
data.columns = data.columns.str.replace('/', '')
data.head()
# Out:
#    Index Country_Region  Confirmed Deaths  Recovered  Active  New_cases  \
# 0      0    Afghanistan      36263   1269      25198    9796      106.0
# 1      1        Albania       4880    144       2745    1991      117.0
# 2      2        Algeria      27973   1163      18837    7973      616.0
# 3      3        Andorra        907     52        803      52       10.0
# 4      4         Angola        950     41        242     667       18.0
#
#    New_deaths  New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  1_week_change  \
# ...

# %%
data.columns
# Out:
# Index(['Index', 'Country_Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New_cases', 'New_deaths', 'New_recovered', 'Deaths___100_Cases',
#        'Recovered___100_Cases', 'Deaths___100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Index                       int64
# Country_Region             object
# Confirmed                   int64
# Deaths                     object
# Recovered                   int64
# Active                      int64
# New_cases                 float64
# New_deaths                float64
# New_recovered               int64
# Deaths___100_Cases        float64
# Recovered___100_Cases     float64
# Deaths___100_Recovered    float64
# Confirmed_last_week         int64
# 1_week_change               int64
# 1_week_%_increase         float64
# WHO_Region                 object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Index                      0
# Country_Region             0
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# New_cases                 10
# New_deaths                10
# New_recovered              0
# Deaths___100_Cases         0
# Recovered___100_Cases      0
# Deaths___100_Recovered     0
# Confirmed_last_week        0
# 1_week_change              0
# 1_week_%_increase          0
# WHO_Region                 0
# dtype: int64

# %%
data.fillna(data.mean)
data.head()
# Out:
#    Index Country_Region  Confirmed Deaths  Recovered  Active New_cases  \
# 0      0    Afghanistan      36263   1269      25198    9796     106.0
# 1      1        Albania       4880    144       2745    1991     117.0
# 2      2        Algeria      27973   1163      18837    7973     616.0
# 3      3        Andorra        907     52        803      52      10.0
# 4      4         Angola        950     41        242     667      18.0
#
#   New_deaths  New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0       10.0             18                3.50                  69.49
# 1        6.0             63                2.95                  56.25
# 2        8.0            749                4.16                  67.34
# 3        0.0              0                5.73                  88.53
# 4        1.0              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  1_week_change  \
# ...

# %%
data.isnull().sum()
# Out:
# Index                     0
# Country_Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths___100_Cases        0
# Recovered___100_Cases     0
# Deaths___100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# dtype: int64

# %%
unique_countries_number = len(data['Country_Region'].unique())
unique_countries_number
# Out:
# 187

# %%
duplicate_countries = data['Country_Region'].duplicated()
duplicate_countries
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: Country_Region, Length: 187, dtype: bool

# %%
data["Confirmed"].mean()
# Out:
# np.float64(88130.935828877)

# %%
data["Confirmed"].median()
# Out:
# np.float64(5059.0)

# %%
data["Confirmed"].std()
# Out:
# np.float64(383318.6638306154)

# %%
mean_of_deaths = data["Deaths"].mean
mean_of_deaths
# Out:
# <bound method Series.mean of 0      1269.0
# 1       144.0
# 2      1163.0
# 3        52.0
# 4        41.0
#         ...
# 182      78.0
# 183       1.0
# 184     483.0
# 185     140.0
# 186       NaN
# Name: Deaths, Length: 187, dtype: float64>

# %%
data["Deaths"].isnull().sum()
# Out:
# np.int64(0)

# %%
data["Deaths"].str.isnumeric()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 182     True
# 183     True
# 184     True
# 185     True
# 186    False
# Name: Deaths, Length: 187, dtype: bool

# %%
data["Deaths"].dtype
# Out:
# dtype('O')

# %%
data["Deaths"] = pd.to_numeric(data["Deaths"],errors='coerce')
data["Deaths"].dtype
# Out:
# dtype('float64')

# %%
data['Deaths']
# Out:
# 0      1269.0
# 1       144.0
# 2      1163.0
# 3        52.0
# 4        41.0
#         ...
# 182      78.0
# 183       1.0
# 184     483.0
# 185     140.0
# 186       NaN
# Name: Deaths, Length: 187, dtype: float64

# %%
data["Deaths"] = data["Deaths"].fillna(mean_of_deaths)
data["Deaths"]
# Out:
# 0                                                 1269.0
# 1                                                  144.0
# 2                                                 1163.0
# 3                                                   52.0
# 4                                                   41.0
#                              ...
# 182                                                 78.0
# 183                                                  1.0
# 184                                                483.0
# 185                                                140.0
# 186    <bound method Series.mean of 0      1269.0\n1 ...
# Name: Deaths, Length: 187, dtype: object

# %%
print(data['Deaths'].dtype)
# Out:
# object

# %%
print(data['Deaths'].unique())
# Out:
# [1269.0 144.0 1163.0 52.0 41.0 3.0 3059.0 711.0 167.0 713.0 423.0 11.0
#  141.0 2965.0 7.0 538.0 9822.0 2.0 35.0 0.0 2647.0 294.0 87618.0 347.0
#  53.0 6.0 1.0 22.0 391.0 8944.0 59.0 75.0 9187.0 4656.0 8777.0 54.0 208.0
#  115.0 96.0 139.0 87.0 19.0 373.0 613.0 58.0 1083.0 5532.0 4652.0 408.0
#  51.0 69.0 34.0 228.0 329.0 30212.0 49.0 8.0 16.0 9125.0 168.0 202.0
#  1761.0 45.0 26.0 20.0 158.0 1166.0 596.0 10.0 33408.0 4838.0 15912.0
#  4458.0 1764.0 474.0 35112.0 998.0 585.0 285.0 185.0 438.0 1301.0 31.0
#  12.0 72.0 64.0 80.0 112.0 91.0 99.0 124.0 15.0 9.0 156.0 44022.0 748.0
#  4.0 316.0 48.0 6160.0 108.0 860.0 466.0 255.0 393.0 5842.0 1322.0 43.0
#  18418.0 1945.0 1676.0 1719.0 165.0 2206.0 13334.0 5.0 42.0 14.0 2760.0
#  194.0 543.0 66.0 27.0 28.0 116.0 93.0 7067.0 300.0 46.0 28432.0 720.0
#  24.0 5700.0 1978.0 40.0 60.0 21.0 18.0 50.0 5630.0 148011.0 1636.0 345.0
#  45844.0 121.0 146.0 78.0 483.0 140.0
#  <bound method Series.mean of 0      1269.0
#  1       144.0
# ...

# %%
data['Deaths'] = pd.to_numeric(data['Deaths'],errors='coerce')
mean_of_death = data['Deaths'].mean()
data['Deaths'] = data['Deaths'].fillna(mean_of_death)
print(data['Deaths'])
data['Deaths'].dtype
# Out:
# 0      1269.000000
# 1       144.000000
# 2      1163.000000
# 3        52.000000
# 4        41.000000
#           ...
# 182      78.000000
# 183       1.000000
# 184     483.000000
# 185     140.000000
# 186    3516.129032
# Name: Deaths, Length: 187, dtype: float64
# dtype('float64')

# %%
data['Deaths'] = data['Deaths'].astype(int)
data['Deaths'].dtype
# Out:
# dtype('int64')

# %%
data.head()
# Out:
#    Index Country_Region  Confirmed  Deaths  Recovered  Active New_cases  \
# 0      0    Afghanistan      36263    1269      25198    9796     106.0
# 1      1        Albania       4880     144       2745    1991     117.0
# 2      2        Algeria      27973    1163      18837    7973     616.0
# 3      3        Andorra        907      52        803      52      10.0
# 4      4         Angola        950      41        242     667      18.0
#
#   New_deaths  New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0       10.0             18                3.50                  69.49
# 1        6.0             63                2.95                  56.25
# 2        8.0            749                4.16                  67.34
# 3        0.0              0                5.73                  88.53
# 4        1.0              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  1_week_change  \
# ...

# %%
data['New_cases'].mean
# Out:
# <bound method Series.mean of 0      106.0
# 1      117.0
# 2      616.0
# 3       10.0
# 4       18.0
#        ...
# 182    152.0
# 183      0.0
# 184     10.0
# 185     71.0
# 186    192.0
# Name: New_cases, Length: 187, dtype: object>

# %%
data['New_deaths'].mean
# Out:
# <bound method Series.mean of 0      10.0
# 1       6.0
# 2       8.0
# 3       0.0
# 4       1.0
#        ...
# 182     2.0
# 183     0.0
# 184     4.0
# 185     1.0
# 186     2.0
# Name: New_deaths, Length: 187, dtype: object>

# %%
total_num_of_deaths = data['Deaths'].sum()
total_num_of_deaths
# Out:
# np.int64(657516)

# %%
total_num_of_recovery = data['Recovered'].sum()
total_num_of_recovery
# Out:
# np.int64(9468087)

# %%
country_totalcases_1million = data[data['Confirmed'] > 1000000]
country_totalcases_1million
# Out:
#      Index Country_Region  Confirmed  Deaths  Recovered   Active New_cases  \
# 23      23         Brazil    2442375   87618    1846641   508116   23284.0
# 79      79          India    1480073   33408     951166   495499   44457.0
# 173    173             US    4290259  148011    1325804  2816444   56336.0
#
#     New_deaths  New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 23       614.0          33728                3.59                  75.61
# 79       637.0          33598                2.26                  64.26
# 173     1076.0          27941                3.45                  30.90
#
#      Deaths___100_Recovered  Confirmed_last_week  1_week_change  \
# 23                     4.74              2118646         323729
# 79                     3.51              1155338         324735
# 173                   11.16              3834677         455582
#
#      1_week_%_increase       WHO_Region  recovery_rate
# ...

# %%
num_of_countries = country_totalcases_1million['Country_Region'].nunique()
num_of_countries
# Out:
# 3

# %%
data['recovery_rate'] = (data['Recovered'] / data['Confirmed']) * 100
data['recovery_rate']
# Out:
# 0      69.486805
# 1      56.250000
# 2      67.339935
# 3      88.533627
# 4      25.473684
#          ...
# 182    35.326240
# 183    80.000000
# 184    49.260792
# 185    61.840949
# 186    20.044379
# Name: recovery_rate, Length: 187, dtype: float64

# %%
country_with_95_recovery_rate = data[data['recovery_rate'] > 95]
country_with_95_recovery_rate
# Out:
#      Index Country_Region  Confirmed  Deaths  Recovered  Active  \
# 24      24         Brunei        141       3        138       0
# 48      48       Djibouti       5059      58       4977      24
# 49      49       Dominica         18       0         18       0
# 69      69        Grenada         23       0         23       0
# 75      75       Holy See         12       0         12       0
# 78      78        Iceland       1854      10       1823      21
# 105    105       Malaysia       8904     124       8601     179
# 110    110      Mauritius        344      10        332       2
# 121    121    New Zealand       1557      22       1514      21
# 126    126         Norway       9132     255       8752     125
# 136    136          Qatar     109597     165     106328    3104
# 164    164        Taiwan*        462       7        440      15
#
#                                              New_cases  \
# 24                                                 0.0
# ...

# %%
data.isnull().sum()
# Out:
# Index                     0
# Country_Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths___100_Cases        0
# Recovered___100_Cases     0
# Deaths___100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# recovery_rate             0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Index', 'Country_Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New_cases', 'New_deaths', 'New_recovered', 'Deaths___100_Cases',
#        'Recovered___100_Cases', 'Deaths___100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region', 'recovery_rate'],
#       dtype='object')

# %%
data[['Confirmed', 'Recovered', 'Active', 'New_cases', 'New_deaths', 'New_recovered', 
      'Deaths___100_Cases', 'Recovered___100_Cases', 'Deaths___100_Recovered', 
      'Confirmed_last_week', '1_week_change', '1_week_%_increase']] = data[
    ['Confirmed', 'Recovered', 'Active', 'New_cases', 'New_deaths', 'New_recovered', 
     'Deaths___100_Cases', 'Recovered___100_Cases', 'Deaths___100_Recovered', 
     'Confirmed_last_week', '1_week_change', '1_week_%_increase']
].apply(pd.to_numeric, errors='coerce')

data.head()
# Out:
#    Index Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  \
# 0      0    Afghanistan      36263    1269      25198    9796      106.0
# 1      1        Albania       4880     144       2745    1991      117.0
# 2      2        Algeria      27973    1163      18837    7973      616.0
# 3      3        Andorra        907      52        803      52       10.0
# 4      4         Angola        950      41        242     667       18.0
#
#    New_deaths  New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  1_week_change  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   187 non-null    int64
#  1   Country_Region          187 non-null    object
#  2   Confirmed               187 non-null    int64
#  3   Deaths                  187 non-null    int64
#  4   Recovered               187 non-null    int64
#  5   Active                  187 non-null    int64
#  6   New_cases               177 non-null    float64
#  7   New_deaths              177 non-null    float64
#  8   New_recovered           187 non-null    int64
#  9   Deaths___100_Cases      187 non-null    float64
#  10  Recovered___100_Cases   187 non-null    float64
#  11  Deaths___100_Recovered  187 non-null    float64
#  12  Confirmed_last_week     187 non-null    int64
#  13  1_week_change           187 non-null    int64
# ...

# %%
data.fillna(data.mean)
data
# Out:
#      Index      Country_Region  Confirmed  Deaths  Recovered  Active  \
# 0        0         Afghanistan      36263    1269      25198    9796
# 1        1             Albania       4880     144       2745    1991
# 2        2             Algeria      27973    1163      18837    7973
# 3        3             Andorra        907      52        803      52
# 4        4              Angola        950      41        242     667
# ..     ...                 ...        ...     ...        ...     ...
# 182    182  West Bank and Gaza      10621      78       3752    6791
# 183    183      Western Sahara         10       1          8       1
# 184    184               Yemen       1691     483        833     375
# 185    185              Zambia       4552     140       2815    1597
# 186    186            Zimbabwe       2704    3516        542    2126
#
#      New_cases  New_deaths  New_recovered  Deaths___100_Cases  \
# 0        106.0        10.0             18                3.50
# ...

# %%
data.isnull().sum()
# Out:
# Index                      0
# Country_Region             0
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# New_cases                 10
# New_deaths                10
# New_recovered              0
# Deaths___100_Cases         0
# Recovered___100_Cases      0
# Deaths___100_Recovered     0
# Confirmed_last_week        0
# 1_week_change              0
# 1_week_%_increase          0
# WHO_Region                 0
# recovery_rate              0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Index                     0
# Country_Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths___100_Cases        0
# Recovered___100_Cases     0
# Deaths___100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# recovery_rate             0
# dtype: int64

# %%
data.tail()
# Out:
#      Index      Country_Region  Confirmed  Deaths  Recovered  Active  \
# 182    182  West Bank and Gaza      10621      78       3752    6791
# 183    183      Western Sahara         10       1          8       1
# 184    184               Yemen       1691     483        833     375
# 185    185              Zambia       4552     140       2815    1597
# 186    186            Zimbabwe       2704    3516        542    2126
#
#      New_cases  New_deaths  New_recovered  Deaths___100_Cases  \
# 182      152.0         2.0              0                0.73
# 183        0.0         0.0              0               10.00
# 184       10.0         4.0             36               28.56
# 185       71.0         1.0            465                3.08
# 186      192.0         2.0             24                1.33
#
#      Recovered___100_Cases  Deaths___100_Recovered  Confirmed_last_week  \
# 182                  35.33                    2.08                 8916
# ...

# %%
data[["New_cases", "New_deaths"]]
# Out:
#      New_cases  New_deaths
# 0        106.0        10.0
# 1        117.0         6.0
# 2        616.0         8.0
# 3         10.0         0.0
# 4         18.0         1.0
# ..         ...         ...
# 182      152.0         2.0
# 183        0.0         0.0
# 184       10.0         4.0
# 185       71.0         1.0
# 186      192.0         2.0
#
# [177 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 177 entries, 0 to 186
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   177 non-null    int64
#  1   Country_Region          177 non-null    object
#  2   Confirmed               177 non-null    int64
#  3   Deaths                  177 non-null    int64
#  4   Recovered               177 non-null    int64
#  5   Active                  177 non-null    int64
#  6   New_cases               177 non-null    float64
#  7   New_deaths              177 non-null    float64
#  8   New_recovered           177 non-null    int64
#  9   Deaths___100_Cases      177 non-null    float64
#  10  Recovered___100_Cases   177 non-null    float64
#  11  Deaths___100_Recovered  177 non-null    float64
#  12  Confirmed_last_week     177 non-null    int64
#  13  1_week_change           177 non-null    int64
# ...

# %%
country_with_95_recovery_rate
# Out:
#      Index Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  \
# 24      24         Brunei        141       3        138       0        0.0
# 48      48       Djibouti       5059      58       4977      24        NaN
# 49      49       Dominica         18       0         18       0        0.0
# 69      69        Grenada         23       0         23       0        0.0
# 75      75       Holy See         12       0         12       0        0.0
# 78      78        Iceland       1854      10       1823      21        7.0
# 105    105       Malaysia       8904     124       8601     179        7.0
# 110    110      Mauritius        344      10        332       2        0.0
# 121    121    New Zealand       1557      22       1514      21        NaN
# 126    126         Norway       9132     255       8752     125       15.0
# 136    136          Qatar     109597     165     106328    3104      292.0
# ...

# %%
data.isnull().sum()
# Out:
# Index                     0
# Country_Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths___100_Cases        0
# Recovered___100_Cases     0
# Deaths___100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# recovery_rate             0
# dtype: int64

# %%
# Out:
# Index                     0
# Country_Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths___100_Cases        0
# Recovered___100_Cases     0
# Deaths___100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# recovery_rate             0
# dtype: int64
